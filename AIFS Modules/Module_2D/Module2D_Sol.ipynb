# %% [markdown]
# ### Module 2D - Optics

# %% [markdown]
# Written for AIFS.
# Copyright 2023 Tarek Zohdi, Emre Mengi. All rights reserved.

# %% [markdown]
# In this assignment, you will be introduced to the basics of optics, which will then lead to modules pertaining light-based simulation methods.

# %%
############################################### Import Packages ##########################################
import numpy as np
import math
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import ipympl # for interactive jupyter notebook plots

# plotting function for interactive plots
def plotInteractive(n,v_f,v_ref):
    # make it an interactive plot
    # %matplotlib widget
    fig = plt.figure(figsize=(5,5))
    ax = fig.add_subplot(111, projection='3d')
    ax.set_xlim([-1,1])
    ax.set_ylim([-1,1])
    ax.set_zlim([-1,1])
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')
    # plot using quiver
    ax.quiver(0,0,0,n[0],n[1],n[2],color='r',label='Normal Vector')
    ax.quiver(0,0,0,v_f[0],v_f[1],v_f[2],color='b',label='Velocity Vector')
    ax.quiver(0,0,0,v_ref[0],v_ref[1],v_ref[2],color='g',label='Reflected Ray Velocity Vector')
    ax.legend()
    plt.show()

# %% [markdown]
# Use the given python notebook template to complete the following coding exercises.

# %% [markdown]
# **Problem 1:** Write a Python function that would take in refractive index, incident velocity vector, and normal vector and calculate the incident angle, reflected velocity, and absorbance. Use the given template code to fill in the blanks in the function **myOptics.**

# %%
############################################### Main Function ################################################

def myOptics(n,v_f,n_hat): #function that will solve for incidence angle,reflected ray velocity, and P_abs
    
    #RELATION: n . v_f. = ||n||.||v_f||.cos(theta_i)
    
    # calculate angle of incidence (theta_i)
    theta_i = np.arccos(np.dot(n,v_f) / (np.linalg.norm(v_f)*np.linalg.norm(n))) #FILL IN HERE
    
    # calculate angle of incidence (theta_i) in degrees
    theta_deg = theta_i * 180 / np.pi #FILL IN HERE
    
    # calculate reflected ray velocity (v_ref)
    v_ref = v_f - 2 * np.dot(n,v_f) * n #FILL IN HERE
    
    # calculate reflectivity (R)
    IR = (1/2)*(((n_hat**2*np.cos(theta_i)-np.sqrt(n_hat**2-np.sin(theta_i)**2))/\
                           (n_hat**2*np.cos(theta_i)+np.sqrt(n_hat**2-np.sin(theta_i)**2)))**2+\
                           ((np.cos(theta_i)-np.sqrt(n_hat**2-np.sin(theta_i)**2))/\
                           (np.cos(theta_i)+np.sqrt(n_hat**2-np.sin(theta_i)**2)))**2) #FILL IN HERE

    # calculate absorbed power (P_abs) as a percentage                
    P_abs = (1-IR)*100  #FILL IN HERE
    
    return theta_deg, list(v_ref), P_abs

# %% [markdown]
# **Problem 2:** For the given surface normal, ray velocity, and surface refractive index combinations, calculate: (a) incidence angle $\theta_i$, (b) ray velocity vector $v_j$ after reflection, (c) percentage of energy absorbed $P_{abs}$ at the surface point. Assume ray velocity magnitude to be the speed of light, $c=3\times 10^8 m/s$ and ambient refractive index to be $n_i=1$.

# %% [markdown]
# **Problem 2.1:** $n=[0.47,-0.58,0.67]$, $v_f=[0.44,-0.58,0.69]$, $n_a=15$

# %%
############################################### Problem 2.1 ################################################

# define normal vector
n = np.array([0.47, -0.58, 0.67]) #FILL IN HERE

# define velocity vector
v_f = np.array([0.44, -0.58, 0.69]) #FILL IN HERE

# define refractive index
n_a = 15 #FILL IN HERE

# call myOptics function
theta_deg, v_ref, P_abs = myOptics(n,v_f,n_a)

print('Incidence angle (deg):',theta_deg) # print angle of incidence
print('Reflected ray velocity:',v_ref) # print reflected ray velocity
print('Absorbed energy (\%):',P_abs) # print absorbed power

# call plotInteractive function
plotInteractive(n,v_f,v_ref)
# Out:
# Incidence angle (deg): 2.0596143604799844
# Reflected ray velocity: [-0.5051699999999999, 0.5863799999999998, -0.65737]
# Absorbed energy (\%): 23.437503145307648
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# **Problem 2.2:** $n=[0.48,-0.58,0.66]$, $v_f=[0.39,-0.58,0.72]$, $n_a=18.99$

# %%
############################################### Problem 2.2 ################################################

# define normal vector
n = np.array([0.48,-0.58,0.66]) #FILL IN HERE

# define velocity vector
v_f = np.array([0.39,-0.58,0.72]) #FILL IN HERE

# define refractive index
n_a = 18.99 #FILL IN HERE

# call myOptics function
theta_deg, v_ref, P_abs = myOptics(n,v_f,n_a)

print('Incidence angle (deg):',theta_deg) # print angle of incidence
print('Reflected ray velocity:',v_ref) # print reflected ray velocity
print('Absorbed energy (\%):',P_abs) # print absorbed power

# call plotInteractive function
plotInteractive(n,v_f,v_ref)
# Out:
# Incidence angle (deg): 6.184805461691832
# Reflected ray velocity: [-0.5688479999999999, 0.5786079999999999, -0.5984160000000001]
# Absorbed energy (\%): 19.0092345017983
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# **Problem 2.3:** $n=[0.30,0.76,0.58]$, $v_f=[0.58,0.50,0.65]$, $n_a=15.38$

# %%
############################################### Problem 2.3 ################################################

# define normal vector
n = np.array([0.30,0.76,0.58]) #FILL IN HERE

# define velocity vector
v_f = np.array([0.58,0.50,0.65]) #FILL IN HERE

# define refractive index
n_a = 15.38 #FILL IN HERE

# call myOptics function
theta_deg, v_ref, P_abs = myOptics(n,v_f,n_a)

print('Incidence angle (deg):',theta_deg) # print angle of incidence
print('Reflected ray velocity:',v_ref) # print reflected ray velocity
print('Absorbed energy (\%):',P_abs) # print absorbed power

# call plotInteractive function
plotInteractive(n,v_f,v_ref)
# Out:
# Incidence angle (deg): 22.326174489064112
# Reflected ray velocity: [0.021399999999999975, -0.9151200000000002, -0.42996]
# Absorbed energy (\%): 22.97448180463202
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# **Problem 2.4:** $n=[0.58,0.23,0.78]$, $v_f=[0.09,-0.58,0.81]$, $n_a=17.69$

# %%
############################################### Problem 2.4 ################################################

# define normal vector
n = np.array([0.58,0.23,0.78]) #FILL IN HERE

# define velocity vector
v_f = np.array([0.09,-0.58,0.81]) #FILL IN HERE

# define refractive index
n_a = 17.69 #FILL IN HERE

# call myOptics function
theta_deg, v_ref, P_abs = myOptics(n,v_f,n_a)

print('Incidence angle (deg):',theta_deg) # print angle of incidence
print('Reflected ray velocity:',v_ref) # print reflected ray velocity
print('Absorbed energy (\%):',P_abs) # print absorbed power

# call plotInteractive function
plotInteractive(n,v_f,v_ref)
# Out:
# Incidence angle (deg): 56.55961900861129
# Reflected ray velocity: [-0.548696, -0.8332759999999999, -0.04893599999999998]
# Absorbed energy (\%): 22.726602489057356
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# **Problem 2.5:** $n=[0.31,-0.58,0.76]$, $v_f=[0.46,0.68,0.58]$, $n_a=14.97$

# %%
############################################### Problem 2.5 ################################################

# define normal vector
n = np.array([0.31,-0.58,0.76]) #FILL IN HERE

# define velocity vector
v_f = np.array([0.46,0.68,0.58]) #FILL IN HERE

# define refractive index
n_a = 14.97 #FILL IN HERE

# call myOptics function
theta_deg, v_ref, P_abs = myOptics(n,v_f,n_a)

print('Incidence angle (deg):',theta_deg) # print angle of incidence
print('Reflected ray velocity:',v_ref) # print reflected ray velocity
print('Absorbed energy (\%):',P_abs) # print absorbed power

# call plotInteractive function
plotInteractive(n,v_f,v_ref)
# Out:
# Incidence angle (deg): 79.21743443478283
# Reflected ray velocity: [0.34282000000000007, 0.89924, 0.29272000000000004]
# Absorbed energy (\%): 41.180664888307916
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# **Problem 2.6:** $n=[0.29,0.76,0.58]$, $v_f=[0.58,0.08,0.81]$, $n_a=1.80$

# %%
############################################### Problem 2.6 ################################################

# define normal vector
n = np.array([0.29,0.76,0.58]) #FILL IN HERE

# define velocity vector
v_f = np.array([0.58,0.08,0.81]) #FILL IN HERE

# define refractive index
n_a = 1.80 #FILL IN HERE

# call myOptics function
theta_deg, v_ref, P_abs = myOptics(n,v_f,n_a)

print('Incidence angle (deg):',theta_deg) # print angle of incidence
print('Reflected ray velocity:',v_ref) # print reflected ray velocity
print('Absorbed energy (\%):',P_abs) # print absorbed power

# call plotInteractive function
plotInteractive(n,v_f,v_ref)
# Out:
# Incidence angle (deg): 45.58504285220705
# Reflected ray velocity: [0.17469600000000002, -0.982176, -0.0006079999999998309]
# Absorbed energy (\%): 90.57054440881525
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# **Problem 2.7:** $n=[0.58,0.49,0.65]$, $v_f=[0.09,-0.58,0.81]$, $n_a=3.79$

# %%
############################################### Problem 2.7 ################################################

# define normal vector
n = np.array([0.58,0.49,0.65]) #FILL IN HERE

# define velocity vector
v_f = np.array([0.09,-0.58,0.81]) #FILL IN HERE

# define refractive index
n_a = 3.79 #FILL IN HERE

theta_deg, v_ref, P_abs = myOptics(n,v_f,n_a) # call myOptics function

print('Incidence angle (deg):',theta_deg) # print angle of incidence
print('Reflected ray velocity:',v_ref) # print reflected ray velocity
print('Absorbed energy (\%):',P_abs) # print absorbed power

# call plotInteractive function
plotInteractive(n,v_f,v_ref)
# Out:
# Incidence angle (deg): 72.86890466290296
# Reflected ray velocity: [-0.25162000000000007, -0.8686100000000001, 0.4271499999999999]
# Absorbed energy (\%): 63.50890713026152
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# **Problem 2.8:** $n=[0.47,-0.58,0.67]$, $v_f=[0.40,0.71,0.58]$, $n_a=11.21$

# %%
############################################### Problem 2.8 ################################################

# define normal vector
n = np.array([0.47,-0.58,0.67]) #FILL IN HERE

# define velocity vector
v_f = np.array([0.40,0.71,0.58]) #FILL IN HERE

# define refractive index
n_a = 11.21 #FILL IN HERE

# call myOptics function
theta_deg, v_ref, P_abs = myOptics(n,v_f,n_a)

print('Incidence angle (deg):',theta_deg) # print angle of incidence
print('Reflected ray velocity:',v_ref) # print reflected ray velocity
print('Absorbed energy (\%):',P_abs) # print absorbed power

# call plotInteractive function
plotInteractive(n,v_f,v_ref)
# Out:
# Incidence angle (deg): 80.54630703632019
# Reflected ray velocity: [0.24508799999999997, 0.901168, 0.3591679999999999]
# Absorbed energy (\%): 48.42126590608964
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# **Problem 2.9:** $n=[0.35,0.74,0.58]$, $v_f=[0,0.82,0.58]$, $n_a=17.58$

# %%
############################################### Problem 2.9 ################################################

# define normal vector
n = np.array([0.35,0.74,0.58]) #FILL IN HERE

# define velocity vector
v_f = np.array([0,0.82,0.58]) #FILL IN HERE

# define refractive index
n_a = 17.58 #FILL IN HERE

# call myOptics function
theta_deg, v_ref, P_abs = myOptics(n,v_f,n_a)

print('Incidence angle (deg):',theta_deg) # print angle of incidence
print('Reflected ray velocity:',v_ref) # print reflected ray velocity
print('Absorbed energy (\%):',P_abs) # print absorbed power

# call plotInteractive function
plotInteractive(n,v_f,v_ref)
# Out:
# Incidence angle (deg): 20.60319589371011
# Reflected ray velocity: [-0.6602399999999999, -0.5759360000000001, -0.514112]
# Absorbed energy (\%): 20.40054176848316
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# **Problem 2.10:** $n=[0.13,0.81,0.58]$, $v_f=[0.28,-0.58,0.77]$, $n_a=19.80$

# %%
############################################### Problem 2.10 ################################################

# define normal vector
n = np.array([0.13,0.81,0.58]) #FILL IN HERE

# define velocity vector
v_f = np.array([0.28,-0.58,0.77]) #FILL IN HERE

# define refractive index
n_a = 19.80 #FILL IN HERE

# call myOptics function
theta_deg, v_ref, P_abs = myOptics(n,v_f,n_a)

print('Incidence angle (deg):',theta_deg) # print angle of incidence
print('Reflected ray velocity:',v_ref) # print reflected ray velocity
print('Absorbed energy (\%):',P_abs) # print absorbed power

# call plotInteractive function
plotInteractive(n,v_f,v_ref)
# Out:
# Incidence angle (deg): 89.25008561585155
# Reflected ray velocity: [0.27656800000000004, -0.6013839999999999, 0.754688]
# Absorbed energy (\%): 32.8471949110352
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
